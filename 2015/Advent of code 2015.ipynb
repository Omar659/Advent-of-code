# %% [markdown]
# # Day 01 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 02 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 03 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 04 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 05 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# # Day 06 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 07 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 08 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 09 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 10 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 11 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 12 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 13 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 14 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 15 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 16 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 17 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 18 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 19 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 20 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 21 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 22 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 23 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 24 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**

# %% [markdown]
# #Day 25 ❌❌

# %% [markdown]
# **FIRST PROBLEM**

# %% [markdown]
# **SECOND PROBLEM**
